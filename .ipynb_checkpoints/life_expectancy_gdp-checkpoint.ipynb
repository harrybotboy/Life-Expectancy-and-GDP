# %% [markdown]
# LIFE EXPECTANCY AND GDP

# %% [markdown]
# The project goals are:
# 1. Which is relationship between life and GDP
# 2. Does GDP and LE increase with time
# 3. What are the average LE and GDP by country
# 4. Does Country effect GDP and LE

# %% [markdown]
# 1. Explore data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels
import matplotlib.pyplot as plt
import math

## Read in Data
gdp_data = pd.read_csv("all_data.csv")

# Rename column
gdp_data.rename(columns={'Life expectancy at birth (years)': 'Age'}, inplace = True)
gdp_data['GDP_log'] = np.log10(gdp_data['GDP'])
print(gdp_data.head(10))
gdp_data.dtypes
# Out:
#   Country  Year   Age           GDP    GDP_log
# 0   Chile  2000  77.3  7.786093e+10  10.891320
# 1   Chile  2001  77.3  7.097992e+10  10.851136
# 2   Chile  2002  77.8  6.973681e+10  10.843462
# 3   Chile  2003  77.9  7.564346e+10  10.878771
# 4   Chile  2004  78.0  9.921039e+10  10.996557
# 5   Chile  2005  78.4  1.229650e+11  11.089782
# 6   Chile  2006  78.9  1.547880e+11  11.189737
# 7   Chile  2007  78.9  1.736060e+11  11.239565
# 8   Chile  2008  79.6  1.796380e+11  11.254398
# 9   Chile  2009  79.3  1.723890e+11  11.236510
# Country     object
# Year         int64
# Age        float64
# GDP        float64
# GDP_log    float64
# dtype: object

# %% [markdown]
# Does GDP and LE increase with time

# %%
#Generate summary stats by Country
gdp_data.groupby('Country').describe()
# Out:
#                           Year                                             \
#                          count    mean       std     min      25%     50%
# Country
# Chile                     16.0  2007.5  4.760952  2000.0  2003.75  2007.5
# China                     16.0  2007.5  4.760952  2000.0  2003.75  2007.5
# Germany                   16.0  2007.5  4.760952  2000.0  2003.75  2007.5
# Mexico                    16.0  2007.5  4.760952  2000.0  2003.75  2007.5
# United States of America  16.0  2007.5  4.760952  2000.0  2003.75  2007.5
# Zimbabwe                  16.0  2007.5  4.760952  2000.0  2003.75  2007.5
#
#                                             Age            ...                \
#                               75%     max count      mean  ...     75%   max
# Country                                                    ...
# Chile                     2011.25  2015.0  16.0  78.94375  ...  79.825  80.5
# China                     2011.25  2015.0  16.0  74.26250  ...  75.250  76.1
# Germany                   2011.25  2015.0  16.0  79.65625  ...  80.525  81.0
# Mexico                    2011.25  2015.0  16.0  75.71875  ...  76.150  76.7
# United States of America  2011.25  2015.0  16.0  78.06250  ...  78.725  79.3
# Zimbabwe                  2011.25  2015.0  16.0  50.09375  ...  55.325  60.7
#
#                            GDP                                            \
#                          count          mean           std           min
# Country
# Chile                     16.0  1.697888e+11  7.687884e+10  6.973681e+10
# China                     16.0  4.957714e+12  3.501096e+12  1.211350e+12
# Germany                   16.0  3.094776e+12  6.674862e+11  1.949950e+12
# Mexico                    16.0  9.766506e+11  2.095716e+11  6.836480e+11
# United States of America  16.0  1.407500e+13  2.432694e+12  1.030000e+13
# Zimbabwe                  16.0  9.062580e+09  4.298310e+09  4.415703e+09
#
#                                                                     \
#                                    25%           50%           75%
# Country
# Chile                     9.387303e+10  1.729975e+11  2.449515e+11
# China                     1.881585e+12  4.075195e+12  7.819550e+12
# Germany                   2.740870e+12  3.396350e+12  3.596078e+12
# Mexico                    7.630910e+11  1.004376e+12  1.156992e+12
# United States of America  1.210000e+13  1.445000e+13  1.567500e+13
# Zimbabwe                  5.748309e+09  6.733671e+09  1.263446e+10
#
#
#                                    max
# Country
# Chile                     2.783840e+11
# China                     1.106470e+13
# Germany                   3.890610e+12
# Mexico                    1.298460e+12
# United States of America  1.810000e+13
# Zimbabwe                  1.630467e+10
#
# [6 rows x 24 columns]

# %% [markdown]
# Find name of countries and years

# %%
countries = gdp_data.Country.unique()
print(countries)

print(sorted(gdp_data.Year.unique()))
# Out:
# ['Chile' 'China' 'Germany' 'Mexico' 'United States of America' 'Zimbabwe']
# [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015]

# %%
# Create plot of Age by Country
sns.boxplot(hue='Country', x='Country', y='Age', data=gdp_data, palette='Accent', legend=False)
plt.xticks(rotation = 30)
plt.title('Age by Country')
plt.show()
plt.clf()

# Create plot of GDP by Country
sns.boxplot(hue='Country', x='Country', y='GDP_log', data=gdp_data, palette='Accent', legend=False)
plt.xticks(rotation = 30)
plt.title('GDP by Country')
plt.show()
plt.clf()

# %% [markdown]
# Plot the change of Life expectancy and GDP by years.

# %%
# Change of GDP by Years
sns.lineplot(x='Year', y='GDP_log', data=gdp_data, hue='Country')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.title("GDP (log transformed) by year for each country")
plt.show()
plt.clf()

# Change of Life Exptectancy by Years
sns.lineplot(x='Year', y='Age', data=gdp_data, hue='Country')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.title("Life Expectancy by year for each country")
plt.show()
plt.clf()
